# %%
import pandas as pd
import numpy as np
import sys

import pylab as plt
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd

# %%
i = 5
df_res_none = pd.read_csv(f'results/SE_run2/results_{i}0.csv')
df_res_low = pd.read_csv(f'results/SE_run2/results_{i}3.csv')
df_res_mid = pd.read_csv(f'results/SE_run2/results_{i}2.csv')
df_res_high = pd.read_csv(f'results/SE_run2/results_{i}1.csv')

df_fdata_none = pd.read_csv(f'results/SE_run2/final_data_{i}0.csv')
df_fdata_low = pd.read_csv(f'results/SE_run2/final_data_{i}3.csv')
df_fdata_mid = pd.read_csv(f'results/SE_run2/final_data_{i}2.csv')
df_fdata_high = pd.read_csv(f'results/SE_run2/final_data_{i}1.csv')

initial_df_comb = pd.read_csv('initial_data/initial_data_2.csv')

# %%
df_res_none.columns
# Out:
# Index(['Unnamed: 0', 'topic', 'post_stance', 'author_id',
#        'num_of_agents_received', 'num_of_agents_not_received',
#        'num_of_spreader_agents', 'num_of_disinterested_agents',
#        'network_polarization', 'net_polarization2', 'network_homophily',
#        'network_homophily2', 'network_polarity', 'satisfaction', 'activity',
#        'user_preference'],
#       dtype='object')

# %%
def plot(df_list, attr):
    
    lab = ['None', 'Low', 'Mid', 'High']
    fig, ax = plt.subplots()
    for i, e in enumerate(df_list):
        temp = e
        plt.plot(range(len(temp)), temp, label=lab[i])
    # ax.legend()
    plt.legend()
    plt.savefig(f"results/fig/{attr}.png", dpi=300, bbox_inches='tight', transparent=True)  # Save as PNG
    # plt.show()

# %%
attr = 'network_polarization'
plot([df_res_none[attr], df_res_low[attr], df_res_mid[attr], df_res_high[attr]], attr)

# %%
df_res_low
# Out:
#        Unnamed: 0  topic  post_stance  author_id  num_of_agents_received  \
# 0               0      6     1.000000        102                      54
# 1               1      5    -1.000000        101                      56
# 2               2      4     1.000000        102                      54
# 3               3      4    -1.000000        101                      61
# 4               4      1     1.000000        101                      60
# ...           ...    ...          ...        ...                     ...
# 19987       19987      2     0.474054        102                      86
# 19988       19988      2     0.580083        102                      86
# 19989       19989      2     0.591633        102                      86
# 19990       19990      2     0.576125        102                      84
# 19991       19991      2     0.703549        102                      84
#
#        num_of_agents_not_received  num_of_spreader_agents  \
# ...

# %%
df_res_none.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'topic', 'post_stance', 'author_id',
#        'num_of_agents_received', 'num_of_agents_not_received',
#        'num_of_spreader_agents', 'num_of_disinterested_agents',
#        'network_polarization', 'net_polarization2', 'network_homophily',
#        'network_homophily2', 'network_polarity', 'satisfaction', 'activity',
#        'user_preference'],
#       dtype='object')

# %%
df_res_none
# Out:
#        Unnamed: 0  topic  post_stance  author_id  num_of_agents_received  \
# 0               0      6     0.000000        100                      81
# 1               1      4    -1.000000        101                      87
# 2               2      2     1.000000        101                      87
# 3               3      2     0.648999        101                      87
# 4               4      2    -0.432549        101                      87
# ...           ...    ...          ...        ...                     ...
# 19987       19987      1     0.316833        101                      51
# 19988       19988      1     0.388906        101                      51
# 19989       19989      1     0.459715        101                      51
# 19990       19990      1     0.223637        101                      56
# 19991       19991      1     0.388051        100                      92
#
#        num_of_agents_not_received  num_of_spreader_agents  \
# ...

# %%
agent_states_cols = ['num_of_agents_received', 'num_of_agents_not_received', 'num_of_spreader_agents', 'num_of_disinterested_agents']

# %%
df_res_none[agent_states_cols].mean()
# Out:
# num_of_agents_received         94.742447
# num_of_agents_not_received      5.257553
# num_of_spreader_agents         12.454032
# num_of_disinterested_agents    66.850690
# dtype: float64

# %%
df_res_low[agent_states_cols].mean()
# Out:
# num_of_agents_received         91.440926
# num_of_agents_not_received      8.559074
# num_of_spreader_agents         12.492597
# num_of_disinterested_agents    64.537265
# dtype: float64

# %%
df_res_med[agent_states_cols].mean()
# Out:
# num_of_agents_received         71.668868
# num_of_agents_not_received     28.331132
# num_of_spreader_agents          6.035514
# num_of_disinterested_agents    50.572729
# dtype: float64

# %%
df_res_high[agent_states_cols].mean()
# Out:
# num_of_agents_received         11.199780
# num_of_agents_not_received     88.800220
# num_of_spreader_agents          0.734944
# num_of_disinterested_agents     8.973339
# dtype: float64

# %%
def get_avg(runs, i):
    
    df_list = []
    for run in range(1, runs):
        temp = pd.read_csv('results/SE_run2/results_' + str(run) + str(i) + '.csv')
        # temp = pd.read_csv('results/SE_run2/final_data_' + str(run) + str(i) +'.csv')
        # temp = pd.read_csv('initial_data/initial_data_' + str(run) +'.csv')
        df_list.append(temp)
        # print(temp.shape)
    #     print(df_temp.columns)
    return sum(df_list) / len(df_list)

# %%
df_fdata_none = get_avg(8, 0)
df_fdata_low = get_avg(8, 3)
df_fdata_mid = get_avg(8, 2)
df_fdata_high = get_avg(8, 1)

# %%
df_res_none = get_avg(8, 0)
df_res_low = get_avg(8, 3)
df_res_mid = get_avg(8, 2)
df_res_high = get_avg(8, 1)

# %%
df = pd.read_csv('results/SE/results_10.csv')

# %%
df
# Out:
#        Unnamed: 0  topic  post_stance  author_id  num_of_agents_received  \
# 0               0      6     0.000000        100                       0
# 1               1      5     0.000000        100                       0
# 2               2      4     0.000000        100                       0
# 3               3      3     0.000000        100                       0
# 4               4      2     0.000000        100                       0
# ...           ...    ...          ...        ...                     ...
# 19987       19987      6    -0.422810        100                       0
# 19988       19988      6    -0.624517        101                       0
# 19989       19989      6    -0.484163        102                       0
# 19990       19990      6    -0.398194        100                       0
# 19991       19991      6     0.440692        101                       0
#
#        num_of_agents_not_received  num_of_spreader_agents  \
# ...

# %%
# import networkx as nx
# import plotly.graph_objects as go

# # G = nx.random_geometric_graph(20, 0.5)
# pos = nx.spring_layout(G, dim=3)
# indegrees = [min(10, G.degree(n)) for n in G.nodes()]
# # Extract coordinates
# xyz = np.array([pos[n] for n in G.nodes()])
# edge_x, edge_y, edge_z = [], [], []
# for u, v in G.edges():
#     edge_x += [pos[u][0], pos[v][0], None]
#     edge_y += [pos[u][1], pos[v][1], None]
#     edge_z += [pos[u][2], pos[v][2], None]

# edge_trace = go.Scatter3d(x=edge_x, y=edge_y, z=edge_z, mode='lines', line=dict(width=2))
# node_trace = go.Scatter3d(x=xyz[:,0], y=xyz[:,1], z=xyz[:,2],
#                           mode='markers', marker=dict(size=indegrees, color=get_colors(df)))

# fig = go.Figure(data=[edge_trace, node_trace])
# fig.update_layout(width=1000, height=800)  # set to desired size
# fig.show()

# %%
import pylab as plt

import seaborn as sns

def get_results(i, attr):
    df_comb = []
    for j in range(3):
        df = pd.read_csv(f'results/SE/final_data_{i}{j}.csv')
        df_res = pd.read_csv(f'results/SE/results_{i}{j}.csv')
        df_comb.append(df_res[attr])
        
    return df_comb

# %%
df_comb = []
j = 0
for i in range(1,3):
    # for j in range(1,4):
    df = pd.read_csv(f'results/SE/final_data_{i}{j}.csv')
    df_res = pd.read_csv(f'results/SE/results_{i}{j}.csv')
    df_comb.append(df_res.satisfaction)

# %%
df_res.shape

# %%
df_res

# %%
i = 1
df_comb = get_results(i, 'activity')
plot(df_comb)

# %%
plot([])

# %%
# Create colormaps
def get_colors(df):

    red_cmap = plt.cm.Reds
    blue_cmap = plt.cm.Blues
    
    from matplotlib.cm import get_cmap
    # import numpy as np

    red_cmap = get_cmap('Reds')(np.linspace(0.4, 0.8, 256))
    blue_cmap = get_cmap('Blues')(np.linspace(0.4, 0.8, 256))

    # Convert to usable colormaps
    from matplotlib.colors import ListedColormap
    red_cmap = ListedColormap(red_cmap)
    blue_cmap = ListedColormap(blue_cmap)


    colors = []
    for v in df['pol_inclination']:
        if v < 0:
            norm_val = abs(v)  # from 0 to 1
            color = red_cmap(norm_val)
        elif v > 0:
            norm_val = abs(v)  # from 0 to 1
            color = blue_cmap(norm_val)
        else:
            color = (0.5, 0, 0.5, 1)  # purle at 0
        colors.append(mcolors.to_hex(color))

    return colors


import matplotlib.pyplot as plt
import networkx as nx

def plot_graph(G, df, isolated):

    # color_map = ['red'] * 50 + ['blue'] * 50 + ['orange', 'green', 'brown']  # Regular, Influential, Superinfluential
    color_map = get_colors(df[~df.index.isin(isolated)])

    indegrees = [G.degree(n) * 10 for n in G.nodes() if n not in isolated]  # Scale for visibility
    print(len(indegrees))

    pos = nx.spring_layout(G)
    # sns.set_style("white")
    # nx.draw(G, pos, with_labels=True)
    # plt.show()

    plt.figure(figsize=(8, 8))
    nx.draw(G, node_color = color_map, with_labels=False, edge_color='gray', alpha=0.8, width=0.5, node_size=indegrees)
    plt.axis('off')
    plt.tight_layout()
    plt.show()
    plt.show()

# %%
i = 2
j = 2
df = pd.read_csv(f'results/SE/final_data_{i}{j}.csv')
df_res = pd.read_csv(f'results/SE/results_{i}{j}.csv')
initial_df = pd.read_csv('initial_data/initial_data_new.csv')

ini_G = None
import pickle
with open('initial_data/graph.pkl', 'rb') as f:
    ini_G = pickle.load(f)

G = None
import pickle
with open(f'results/SE/graph_{i}{j}.pkl', 'rb') as f:
    G = pickle.load(f)
    
isolated = list(nx.isolates(G))
G.remove_nodes_from(isolated)
print(isolated)

plot_graph(G, df, isolated)
# Out:
# []
# 103

# %%
plot_graph(ini_G, initial_df, [])
# Out:
# 103

# %%
# plot_graph(G, df)

# %%
G.number_of_edges()

# %%
for i in range(103):
    print(i, len(list(G.edges(i))))

# %%
2 * ini_G.number_of_edges() / ini_G.number_of_nodes()
2 * G.number_of_edges() / G.number_of_nodes()

# %%
df = get_results(4, ['num_of_agents_received', 'num_of_agents_not_received'])
df[0].mean(), df[1].mean(), df[2].mean()

# %%
plot(get_results(5, 'author_id'))

# %%
plot(df_comb)

# %%
df_res.author_id.value_counts()

# %%
cols = ['topic_1', 'topic_2', 'topic_3',
       'topic_4', 'topic_5', 'topic_6', 'privacy', 'activity', 'satisfaction',
       'lat_acc', 'lat_rej', 'id', 'pol_inclination']

# %%
(df[cols] == initial_df[cols]).satisfaction.value_counts()

# %%
import warnings
warnings.filterwarnings('ignore')

def get_data_plot_grid(df):

    fig = plt.figure(figsize=(25, 6))
    #fig.subplots_adjust(hspace=0.4, wspace=0.4)
    ax = fig.add_subplot(2, 6, 1)
    sns.distplot(df.activity,ax=ax)
#     ax = fig.add_subplot(2, 6, 2)
#     sns.distplot(df.pol_interest,ax=ax)
#     ax = fig.add_subplot(2, 6, 3)
#     sns.distplot(df.privacy_preference,ax=ax)
    ax = fig.add_subplot(2, 6, 2)
    sns.distplot(df.pol_inclination,ax=ax)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    ax = fig.add_subplot(2, 6, 7)
    sns.distplot(df.topic_1,ax=ax)
    ax = fig.add_subplot(2, 6, 8)
    sns.distplot(df.topic_2,ax=ax)
    ax = fig.add_subplot(2, 6, 9)
    sns.distplot(df.topic_3,ax=ax)
    ax = fig.add_subplot(2, 6, 10)
    sns.distplot(df.topic_4,ax=ax)
    ax = fig.add_subplot(2, 6, 11)
    sns.distplot(df.topic_5,ax=ax)
    ax = fig.add_subplot(2, 6, 12)
    sns.distplot(df.topic_6,ax=ax)
    plt.show()

# %%
df[(df[cols] == initial_df[cols]).satisfaction == False]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df[(df[cols] == initial_df[cols]).satisfaction == False]
#
# NameError: name 'cols' is not defined

# %%
# df_res_none = pd.read_csv('results/SE_run_20k-2/results_combined_None_SE.csv')
# df_res_low = pd.read_csv('results/SE_run_20k-2/results_combined_low_SE.csv')
# df_res_med = pd.read_csv('results/SE_run_20k-2/results_combined_med_SE.csv')
# df_res_high = pd.read_csv('results/SE_run_20k-2/results_combined_high_SE.csv')

# df = pd.read_csv('results/SE_run_20k-2/final_data_combined_none_SE.csv')
# df = pd.read_csv('results/SE/final_data_10.csv')
# df = pd.read_csv('results/SE_run_20k-2/final_data_combined_med_SE.csv')
# df = pd.read_csv('results/SE_run_20k-2/final_data_combined_high_SE.csv')

get_data_plot_grid(df_fdata_high)

# %%
initial_df = pd.read_csv('initial_data/initial_data_1.csv')

# %%
get_data_plot_grid(initial_df)

# %%
df_res.columns

# %%
attr = 'net_polarization2'
exp = [df_res[attr]]
plot(exp, attr)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 3
#       1 attr = 'net_polarization2'
#       2 exp = [df_res[attr]]
# ----> 3 plot(exp, attr)
#
# Cell In[23], line 10, in plot(df_list, attr)
#       8 # ax.legend()
#       9 plt.legend()
# ---> 10 plt.savefig(f"results/fig/{attr}.png", dpi=300, bbox_inches='tight', transparent=True)
#
# File ~/venv/my_venv/lib/python3.8/site-packages/matplotlib/pyplot.py:1023, in savefig(*args, **kwargs)
#    1020 @_copy_docstring_and_deprecators(Figure.savefig)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# File ~/venv/my_venv/lib/python3.8/site-packages/matplotlib/figure.py:3378, in Figure.savefig(self, fname, transparent, **kwargs)
# ...

# %%
df_res

# %%
df_res.author_id.value_counts()
